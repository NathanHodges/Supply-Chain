# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import preprocessing 

df = pd.read_csv('SCMS.csv' , usecols = [i for i in range(33)] ,encoding = 'Latin1')
df = df.fillna('NaN')
df['Scheduled Delivery Date'] = pd.to_datetime(df['Scheduled Delivery Date'])
df['Delivered to Client Date'] = pd.to_datetime(df['Delivered to Client Date'])
df['Delivery Recorded Date'] = pd.to_datetime(df['Delivery Recorded Date'])

df = df.sort_values(by = 'Scheduled Delivery Date')
df = df.reset_index()

# def pie_chart(col):
#             mode = df.iloc[ : , find(col)]
#             unique_mode = mode.unique()

#             num_of_unique = []
#             for i in range(len(unique_mode)):
#                 num_of_unique.append(sum(df.iloc[ : , find(col)] == unique_mode[i]))

#             plt.pie(num_of_unique, labels = unique_mode)
#             plt.axis('equal')
#             return plt.show()

def find(col) :
    return list(df.columns).index(col)       

# def total_column(col):
#         idx_col_cost = find(col)
#         col_cost = df.iloc[: ,find(col) ]
#         col_cost_range = range(len(col_cost))

#         clean_col_cost = []
#         for i in col_cost_range:
#             try:
#                 clean_col_cost.append(float(col_cost[i]))
#             except:
#                 clean_col_cost.append(0)
#         return round(sum(clean_col_cost),2)

def dates(row,dataframe): 
    
    scheduled = dataframe.iloc[ : , find('Scheduled Delivery Date')]   
    delivered = dataframe.iloc[ : , find('Delivered to Client Date')]
    recorded_deliver = dataframe.iloc[ : , find('Delivery Recorded Date')]
    
    return [scheduled[row], delivered[row], recorded_deliver[row]]

# zero_matrix = np.zeros((3,5))
# mode = df.iloc[ : , find('Shipment Mode')]
# unique_mode = mode.unique()

# for i in range(len(df.index)):
    
#     # On Time
#     if dates(i,dataframe = df)[0] == dates(i,dataframe = df)[1]:
#         if df.iloc[ i , find('Shipment Mode')] == mode.unique()[0]:
#             zero_matrix[0 , 0] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[1]:
#             zero_matrix[0 , 1] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[2]:
#             zero_matrix[0 , 2] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[3]:
#             zero_matrix[0 , 3] +=1
#         else:
#             zero_matrix[0 , 4] +=1
        
#     #Early      
#     elif dates(i,dataframe = df)[0] < dates(i,dataframe = df)[1]:
#         if df.iloc[ i , find('Shipment Mode')] == mode.unique()[0]:
#             zero_matrix[1 , 0] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[1]:
#             zero_matrix[1 , 1] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[2]:
#             zero_matrix[1 , 2] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[3]:
#             zero_matrix[1 , 3] +=1
#         else:
#             zero_matrix[1 , 4] +=1
        
#     #Late
#     elif dates(i,dataframe = df)[0] > dates(i,dataframe = df)[1] :
#         if df.iloc[ i , find('Shipment Mode')] == mode.unique()[0]:
#             zero_matrix[2 , 0] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[1]:
#             zero_matrix[2 , 1] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[2]:
#             zero_matrix[2 , 2] +=1
#         elif df.iloc[ i , find('Shipment Mode')] == mode.unique()[3]:
#             zero_matrix[2 , 3] +=1
#         else:
#             zero_matrix[2 , 4] +=1

# percent_matrix = np.round(zero_matrix/sum(zero_matrix) , 2)

# dic = {mode.unique()[i]: list(percent_matrix[: ,i ]) for i in range(len(mode.unique()))}

# df1 = pd.DataFrame(dic)
# df1.index = ['On Time' , 'Early' ,'Late']

# pie_chart('Shipment Mode')

value_attend = []
for i in range(len(df.index)):
    
    # On Time
    if dates(i,dataframe = df)[0] == dates(i,dataframe = df)[1]:
        value_attend.append('On Time')
        
    #Early      
    elif dates(i,dataframe = df)[0] < dates(i,dataframe = df)[1]:
        value_attend.append('Early')
        
    #Late
    elif dates(i,dataframe = df)[0] > dates(i,dataframe = df)[1] :
        value_attend.append('Late')

# index = [0]
# N = range(len(df.index))
# for i in N:
#     time_delta = df['Scheduled Delivery Date'][i] - df['Scheduled Delivery Date'][index[-1]]
#     time_delta = time_delta.days
#     if 20 < time_delta < 40:
#         index.append(i)
#         origin = df['Scheduled Delivery Date'][i]
#     else:
#         pass

# if index[-1] < N[-1]:
#     index[-1] = N[-1]
#     time_delta = df['Scheduled Delivery Date'][index[-1]] - df['Scheduled Delivery Date'][index[-2]]
#     time_delta = time_delta.days
# else:
#     pass

# Early_By_Interval = []
# On_Time_By_Interval = []
# Late_By_Interval = []

# for i in range(len(index)-1):
#     Early = value_attend[index[i]:index[i+1]].count('Early')
#     Early_By_Interval.append(Early)
    
#     On_Time = value_attend[index[i]:index[i+1]].count('On Time')
#     On_Time_By_Interval.append(On_Time)
    
#     Late = value_attend[index[i]:index[i+1]].count('Late')
#     Late_By_Interval.append(Late)

# Number_Intervals = [i for i in range(len(index)-1)]

# Total_Ship_By_Interval = [sum(x) for x in zip(Early_By_Interval, On_Time_By_Interval, Late_By_Interval)]
# Normalize_Early = [x / y for x, y in zip(Early_By_Interval , Total_Ship_By_Interval)]
# Normalize_On = [x / y for x, y in zip(On_Time_By_Interval , Total_Ship_By_Interval)]
# Normalize_Late = [x / y for x, y in zip(Late_By_Interval , Total_Ship_By_Interval)]

# plt.plot(Number_Intervals, 
#          Normalize_Early, 
#          'or',markersize = 2,
#          label = 'Early')

# plt.plot(Number_Intervals,
#          Normalize_On,
#          'ob',markersize = 2,
#          label = 'On Time')

# plt.plot(Number_Intervals,
#          Normalize_Late,
#          'og',markersize = 2,
#          label = 'Late')

# plt.legend()
# plt.show()

# df1

df['target'] = value_attend

variables = ['Shipment Mode','Unit of Measure (Per Pack)','Line Item Quantity','Line Item Value','Pack Price','Unit Price','target']

exclude = [x for x in list(df.columns) if x not in variables]

df = df.drop(exclude , axis = 1)

for i in range(len(df.index)):
    try:
        type(float(df.iloc[ i, find('Unit of Measure (Per Pack)')])) == float
        type(float(df.iloc[ i, find('Line Item Quantity')]))         == float
        type(float(df.iloc[ i, find('Line Item Value')]))            == float
        type(float(df.iloc[ i, find('Pack Price')]))                 == float
        type(float(df.iloc[ i, find('Unit Price')]))                 == float
    except:
        df = df.drop(i)
        
df.head()
# Out:
#   Shipment Mode  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0           Air                          30                  31
# 1           Air                          25                  44
# 2           Air                          30                  19
# 3           Air                          40                 147
# 4           Air                         100                   6
#
#    Line Item Value  Pack Price  Unit Price   target
# 0           734.70       23.70        0.79  On Time
# 1          1375.00       31.25        1.25  On Time
# 2           551.00       29.00        0.97  On Time
# 3         11076.45       75.35        1.88  On Time
# 4          2400.00      400.00        4.00  On Time

# %%
le = preprocessing.LabelEncoder()
df['Shipment Mode'] = le.fit_transform(df['Shipment Mode'])
df.iloc[:,[0,1,2,3,4,5]].head()
# Out:
#    Shipment Mode  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0              0                          30                  31
# 1              0                          25                  44
# 2              0                          30                  19
# 3              0                          40                 147
# 4              0                         100                   6
#
#    Line Item Value  Pack Price  Unit Price
# 0           734.70       23.70        0.79
# 1          1375.00       31.25        1.25
# 2           551.00       29.00        0.97
# 3         11076.45       75.35        1.88
# 4          2400.00      400.00        4.00

# %%
y = df.target

X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,[0,1]], y, test_size = 0.2)

for i in range(1,15):

    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train) 

    y_pred = knn.predict(X_test )
    
    accuracy = metrics.accuracy_score(y_test,y_pred)
    
    print(accuracy , i)
# Out:
# 0.6334140435835351 1
# 0.559322033898305 2
# 0.612590799031477 3
# 0.6271186440677966 4
# 0.6324455205811138 5
# 0.636319612590799 6
# 0.6479418886198547 7
# 0.6484261501210654 8
# 0.6518159806295399 9
# 0.6513317191283293 10
# 0.6523002421307506 11
# 0.6493946731234866 12
# 0.648910411622276 13
# 0.648910411622276 14

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train, y_train) 

y_pred = knn.predict(X_test )
    
accuracy = metrics.accuracy_score(y_test,y_pred)
print('Accuracy:' , metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.6518159806295399

# %%
from bokeh.plotting import figure, output_file, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
output_file("lines.html")

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
